# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ## 1. Problem Understanding
# a) Defining problem statement
#
# b) Need of the study/project
#
# c) Understanding business/social opportunity

# %% [markdown]
# ## 2. Data Report
# a) Understanding how data was collected in terms of time, frequency and methodology
#
# b) Visual inspection of data (rows, columns, descriptive details)
#
# c) Understanding of attributes (variable info, renaming if required)

# %%
df = pd.read_csv('Social+Media+Data+for+DSBA.csv')

# %%
# This the head of our data
df.head(10)
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
# 5  1000006            No                           240.0              iOS
# 6  1000007            No                             NaN  iOS and Android
# 7  1000008            No                           225.0  iOS and Android
# 8  1000009            No                           285.0              iOS
# 9  1000010            No                           270.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                  38570.0                              1
# 1                                   9765.0                              1
# 2                                  48055.0                              1
# 3                                  48720.0                              1
# 4                                  20685.0                              1
# 5                                  35175.0                              1
# 6                                  46340.0                              1
# 7                                      NaN                             24
# 8                                   7560.0                             23
# 9                                  45465.0                             27
#
#   member_in_family preferred_location_type  Yearly_avg_comment_on_travel_page  \
# 0                2               Financial                               94.0
# 1                1               Financial                               61.0
# 2                2                   Other                               92.0
# 3                4               Financial                               56.0
# 4                1                 Medical                               40.0
# 5                2               Financial                               79.0
# 6            Three                 Medical                               81.0
# 7                1               Financial                               67.0
# 8                3               Financial                               44.0
# 9                3                     NaN                               94.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                          5993
# 1                                          5130
# 2                                          2090
# 3                                          2909
# 4                                          3468
# 5                                          3068
# 6                                          2670
# 7                                          2693
# 8                                          9526
# 9                                          5237
#
#    week_since_last_outstation_checkin following_company_page  \
# 0                                   8                    Yes
# 1                                   1                     No
# 2                                   6                    Yes
# 3                                   1                    Yes
# 4                                   9                     No
# 5                                   0                     No
# 6                                   4                    Yes
# 7                                   1                     No
# 8                                   0                     No
# 9                                   6                     No
#
#    montly_avg_comment_on_company_page working_flag  travelling_network_rating  \
# 0                                  11           No                          1
# 1                                  23          Yes                          4
# 2                                  15           No                          2
# 3                                  11           No                          3
# 4                                  12           No                          4
# 5                                  13           No                          3
# 6                                  20          Yes                          1
# 7                                  22          Yes                          2
# 8                                  21          Yes                          2
# 9                                  13           No                          2
#
#    Adult_flag  Daily_Avg_mins_spend_on_traveling_page
# 0           0                                       8
# 1           1                                      10
# 2           0                                       7
# 3           0                                       8
# 4           1                                       6
# 5           0                                       8
# 6           3                                      12
# 7           1                                       1
# 8           0                                      10
# 9           2                                      17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  object
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  object
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11685 non-null  object
#  6   member_in_family                              11760 non-null  object
#  7   preferred_location_type                       11729 non-null  object
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11657 non-null  object
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  object
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(3), int64(7), object(7)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (11760, 17)

# %%
df.describe().T
# Out:
#                                                 count          mean  \
# UserID                                        11760.0  1.005880e+06
# Yearly_avg_view_on_travel_page                11179.0  2.808308e+02
# total_likes_on_outstation_checkin_given       11379.0  2.817048e+04
# Yearly_avg_comment_on_travel_page             11554.0  7.479003e+01
# total_likes_on_outofstation_checkin_received  11760.0  6.531699e+03
# week_since_last_outstation_checkin            11760.0  3.203571e+00
# montly_avg_comment_on_company_page            11760.0  2.866156e+01
# travelling_network_rating                     11760.0  2.712245e+00
# Adult_flag                                    11760.0  7.938776e-01
# Daily_Avg_mins_spend_on_traveling_page        11760.0  1.381743e+01
#
#                                                        std        min  \
# UserID                                         3394.963917  1000001.0
# Yearly_avg_view_on_travel_page                   68.182958       35.0
# total_likes_on_outstation_checkin_given       14385.032134     3570.0
# Yearly_avg_comment_on_travel_page                24.026650        3.0
# total_likes_on_outofstation_checkin_received   4706.613785     1009.0
# week_since_last_outstation_checkin                2.616365        0.0
# montly_avg_comment_on_company_page               48.660504       11.0
# travelling_network_rating                         1.080887        1.0
# Adult_flag                                        0.851823        0.0
# Daily_Avg_mins_spend_on_traveling_page            9.070657        0.0
#
#                                                      25%        50%  \
# UserID                                        1002940.75  1005880.5
# Yearly_avg_view_on_travel_page                    232.00      271.0
# total_likes_on_outstation_checkin_given         16380.00    28076.0
# Yearly_avg_comment_on_travel_page                  57.00       75.0
# total_likes_on_outofstation_checkin_received     2940.75     4948.0
# week_since_last_outstation_checkin                  1.00        3.0
# montly_avg_comment_on_company_page                 17.00       22.0
# travelling_network_rating                           2.00        3.0
# Adult_flag                                          0.00        1.0
# Daily_Avg_mins_spend_on_traveling_page              8.00       12.0
#
#                                                      75%        max
# UserID                                        1008820.25  1011760.0
# Yearly_avg_view_on_travel_page                    324.00      464.0
# total_likes_on_outstation_checkin_given         40525.00   252430.0
# Yearly_avg_comment_on_travel_page                  92.00      815.0
# total_likes_on_outofstation_checkin_received     8393.25    20065.0
# week_since_last_outstation_checkin                  5.00       11.0
# montly_avg_comment_on_company_page                 27.00      500.0
# travelling_network_rating                           4.00        4.0
# Adult_flag                                          1.00        3.0
# Daily_Avg_mins_spend_on_traveling_page             18.00      270.0

# %%
df.isnull().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                  581
# preferred_device                                 53
# total_likes_on_outstation_checkin_given         381
# yearly_avg_Outstation_checkins                   75
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page               206
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %% [markdown]
# #### We have quite a few null values in some columns. Further we will impute these null values by using Average or median or mode for categorical and numeric variables.

# %%
df.duplicated().sum()

# No duplicate values found.
# Out:
# 0

# %%
df.select_dtypes(include=['object']).dtypes
# Out:
# Taken_product                     object
# preferred_device                  object
# yearly_avg_Outstation_checkins    object
# member_in_family                  object
# preferred_location_type           object
# following_company_page            object
# working_flag                      object
# dtype: object

# %%
df.select_dtypes(include=['float']).dtypes
# Out:
# Yearly_avg_view_on_travel_page             float64
# total_likes_on_outstation_checkin_given    float64
# Yearly_avg_comment_on_travel_page          float64
# dtype: object

# %%
df.select_dtypes(include=['int64']).dtypes
# Out:
# UserID                                          int64
# total_likes_on_outofstation_checkin_received    int64
# week_since_last_outstation_checkin              int64
# montly_avg_comment_on_company_page              int64
# travelling_network_rating                       int64
# Adult_flag                                      int64
# Daily_Avg_mins_spend_on_traveling_page          int64
# dtype: object

# %% [markdown]
# #### The object dtypes need to be changed to numeric types for further analysis.

# %%
df['Taken_product'].value_counts()
# Out:
# No     9864
# Yes    1896
# Name: Taken_product, dtype: int64

# %%
df['preferred_device'].value_counts()
# Out:
# Tab                4172
# iOS and Android    4134
# Laptop             1108
# iOS                1095
# Mobile              600
# Android             315
# Android OS          145
# ANDROID             134
# Other                 2
# Others                2
# Name: preferred_device, dtype: int64

# %% [markdown]
# ##### We can see that Other and Others can be assumed to be the same and hence we will replace ones value with the other.

# %%
df['preferred_device'].value_counts()
# Out:
# Tab                4172
# iOS and Android    4134
# Laptop             1108
# iOS                1095
# Mobile              600
# Android             315
# Android OS          145
# ANDROID             134
# Other                 2
# Others                2
# Name: preferred_device, dtype: int64

# %%
df['member_in_family'].value_counts()
# Out:
# 3        4561
# 4        3184
# 2        2256
# 1        1349
# 5         384
# Three      15
# 10         11
# Name: member_in_family, dtype: int64

# %% [markdown]
# ##### Further we will replace Three with the number 3 as it is ok to assume that it is the same.

# %%
df['preferred_location_type'].value_counts()
# Out:
# Beach              2424
# Financial          2409
# Historical site    1856
# Medical            1845
# Other               643
# Big Cities          636
# Social media        633
# Trekking            528
# Entertainment       516
# Hill Stations       108
# Tour  Travel         60
# Tour and Travel      47
# Game                 12
# OTT                   7
# Movie                 5
# Name: preferred_location_type, dtype: int64

# %% [markdown]
# ###### We can see that Tour Travel and Tour and Travel can be assumed to be the same and hence we will replace ones value with the other.

# %%
df['preferred_location_type'].value_counts()
# Out:
# Beach              2424
# Financial          2409
# Historical site    1856
# Medical            1845
# Other               643
# Big Cities          636
# Social media        633
# Trekking            528
# Entertainment       516
# Hill Stations       108
# Tour  Travel         60
# Tour and Travel      47
# Game                 12
# OTT                   7
# Movie                 5
# Name: preferred_location_type, dtype: int64

# %%
df['following_company_page'].value_counts()
# Out:
# No     8355
# Yes    3285
# 1        12
# 0         5
# Name: following_company_page, dtype: int64

# %% [markdown]
# ##### For the moment we will replace 0 with No and 1 with Yes for the purpose of univariate analysis. Further we will change the values vice versa for labelling.

# %%
df['following_company_page'].value_counts()
# Out:
# No     8355
# Yes    3285
# 1        12
# 0         5
# Name: following_company_page, dtype: int64

# %%
df['working_flag'].value_counts()
# Out:
# No     9952
# Yes    1808
# Name: working_flag, dtype: int64

# %%
df['yearly_avg_Outstation_checkins'].value_counts()
# Out:
# 1     4543
# 2      844
# 10     682
# 9      340
# 3      336
# 7      336
# 8      320
# 5      261
# 4      256
# 16     255
# 6      236
# 11     229
# 24     223
# 29     215
# 23     215
# 18     208
# 15     206
# 26     199
# 20     199
# 25     198
# 28     180
# 19     176
# 14     167
# 17     160
# 12     159
# 22     152
# 13     150
# 21     143
# 27      96
# *        1
# Name: yearly_avg_Outstation_checkins, dtype: int64

# %% [markdown]
# ##### We can see a special character here '*' that needs to be replaced with a value¶

# %% [markdown]
# ## 3. Exploratory Data Analysis
# a) Univariate analysis (distribution and spread for every continuous attribute, distribution of data in categories for categorical ones)
#
# b) Bivariate analysis (relationship between different variables , correlations)
#
# c) Removal of unwanted variables (if applicable)
#
# b) Missing Value treatment (if applicable)
#
# d) Outlier treatment (if required)
#
# e) Variable transformation (if applicable)
#
# f) Addition of new variables (if required)

# %% [markdown]
# ### a)  Univariate analysis (distribution and spread for every continuous attribute, distribution of data in categories for categorical ones)

# %% [markdown]
# ###### Count plots of Categorical data

# %%
plt.figure(figsize = (10,5))
sns.countplot(df['Taken_product'], palette="Set3")    
plt.show()

# %%
product_taken= df.Taken_product.value_counts()[1]
product_not_taken = df.Taken_product.value_counts()[0]
names = ['product purchased before','product was not purchased before']
size  = [product_taken,product_not_taken]

plt.pie(size, labels=names, colors=['lightgreen','silver'], 
        autopct='%.2f%%',pctdistance=1.28, 
        wedgeprops={'linewidth':7, 'edgecolor':'white'})


my_circle = plt.Circle((0,0), 0.6, color='white')


fig = plt.gcf()
fig.set_size_inches(7,7)
fig.gca().add_artist(my_circle)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(df['preferred_device'], palette="Set3")    
plt.show()

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='preferred_location_type',data=df,palette="Set3")    
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(df['following_company_page'], palette="Set3")    
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(df['working_flag'], palette="Set3")    
plt.show()

# %% [markdown]
# # Labeling Categorical data

# %%
df['Taken_product']=np.where(df['Taken_product'] =='No','0', df['Taken_product'])
df['Taken_product']=np.where(df['Taken_product'] =='Yes', '1', df['Taken_product'])

# %% [markdown]
# ###### Labelling people who have made a purchase with the company as '1' and people who have not made a purchase as '0'

# %%
df['preferred_device']=np.where(df['preferred_device'] =='Laptop', '0', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Android', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Android OS', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='ANDROID', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Mobile', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Other', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Others', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='Tab', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='iOS', '1', df['preferred_device'])
df['preferred_device']=np.where(df['preferred_device'] =='iOS and Android', '1', df['preferred_device'])

# %% [markdown]
# ##### Anything which is not a laptop can be considered as mobile phone usage. Labelling users who are using Laptop as '0' and people who are using anything else as '1'

# %%
df['member_in_family']=np.where(df['member_in_family'] =='Three', '3', df['member_in_family'])

# %% [markdown]
# ###### Combining the family with 'Three' family members with families with '3' members.

# %%
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Beach', '0', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Big Cities', '1', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Entertainment', '2', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Financial', '3', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Game', '4', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Hill Stations', '5', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Historical site', '6', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Medical', '7', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Movie', '8', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='OTT', '9', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Other', '10', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Social media', '11', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Tour  Travel', '12', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Tour and Travel', '12', df['preferred_location_type'])
df['preferred_location_type']=np.where(df['preferred_location_type'] =='Trekking', '13', df['preferred_location_type'])

# %% [markdown]
# ###### Labelling all the preferred location with unique values from '0' to '13'

# %%
df['following_company_page']=np.where(df['following_company_page'] =='No', '0', df['following_company_page'])
df['following_company_page']=np.where(df['following_company_page'] =='Yes', '1', df['following_company_page'])

# %% [markdown]
# ###### Labelling users who have been following the company page with '0' and users who have not been following the company page with '1'

# %%
df['working_flag']=np.where(df['working_flag'] =='No', '0', df['working_flag'])
df['working_flag']=np.where(df['working_flag'] =='Yes', '1', df['working_flag'])

# %% [markdown]
# ##### Labelling users who work as '1' and users who do not work as '0'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  object
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  object
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11685 non-null  object
#  6   member_in_family                              11760 non-null  object
#  7   preferred_location_type                       11729 non-null  object
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11657 non-null  object
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  object
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(3), int64(7), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# ### We will change all the variables to numeric data type

# %%
df.select_dtypes(include=['object']).dtypes
# Out:
# Taken_product                     object
# preferred_device                  object
# yearly_avg_Outstation_checkins    object
# member_in_family                  object
# preferred_location_type           object
# following_company_page            object
# working_flag                      object
# dtype: object

# %%
df['yearly_avg_Outstation_checkins'] = pd.to_numeric(df['yearly_avg_Outstation_checkins'], errors='coerce')
df['member_in_family'] = pd.to_numeric(df['member_in_family'], errors='coerce')
df['Taken_product'] = pd.to_numeric(df['Taken_product'], errors='coerce')
df['preferred_device'] = pd.to_numeric(df['preferred_device'], errors='coerce')
df['preferred_location_type'] = pd.to_numeric(df['preferred_location_type'], errors='coerce')
df['following_company_page'] = pd.to_numeric(df['following_company_page'], errors='coerce')
df['working_flag'] = pd.to_numeric(df['working_flag'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  int64
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  float64
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11684 non-null  float64
#  6   member_in_family                              11760 non-null  int64
#  7   preferred_location_type                       11729 non-null  float64
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11657 non-null  float64
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  int64
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 1.5 MB

# %%
df.isnull().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                  581
# preferred_device                                 53
# total_likes_on_outstation_checkin_given         381
# yearly_avg_Outstation_checkins                   76
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page               206
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %% [markdown]
# ### Imputing Null values
#
# ##### We will impute numeric values with median and categorical values with mode.

# %%
df['Yearly_avg_view_on_travel_page'].fillna(int(df['Yearly_avg_view_on_travel_page'].median()), inplace=True)

# %%
df['total_likes_on_outstation_checkin_given'].fillna(int(df['total_likes_on_outstation_checkin_given'].median()), inplace=True)

# %%
df['Yearly_avg_comment_on_travel_page'].fillna(df['Yearly_avg_comment_on_travel_page'].median(), inplace=True)

# %%
df['yearly_avg_Outstation_checkins'].fillna(df['yearly_avg_Outstation_checkins'].median(), inplace=True)

# %%
df['preferred_device'].fillna(df['preferred_device'].mode, inplace=True)

# %%
df['member_in_family'].fillna(df['member_in_family'].mode, inplace=True)

# %%
df['preferred_location_type'].fillna(df['preferred_location_type'].mode, inplace=True)

# %%
df['following_company_page'].fillna(df['following_company_page'].mode, inplace=True)

# %%
df.shape
# Out:
# (11760, 17)

# %%
df.isnull().sum()
# Out:
# UserID                                          0
# Taken_product                                   0
# Yearly_avg_view_on_travel_page                  0
# preferred_device                                0
# total_likes_on_outstation_checkin_given         0
# yearly_avg_Outstation_checkins                  0
# member_in_family                                0
# preferred_location_type                         0
# Yearly_avg_comment_on_travel_page               0
# total_likes_on_outofstation_checkin_received    0
# week_since_last_outstation_checkin              0
# following_company_page                          0
# montly_avg_comment_on_company_page              0
# working_flag                                    0
# travelling_network_rating                       0
# Adult_flag                                      0
# Daily_Avg_mins_spend_on_traveling_page          0
# dtype: int64

# %%
df['yearly_avg_Outstation_checkins'] = pd.to_numeric(df['yearly_avg_Outstation_checkins'], errors='coerce')
df['member_in_family'] = pd.to_numeric(df['member_in_family'], errors='coerce')
df['Taken_product'] = pd.to_numeric(df['Taken_product'], errors='coerce')
df['preferred_device'] = pd.to_numeric(df['preferred_device'], errors='coerce')
df['preferred_location_type'] = pd.to_numeric(df['preferred_location_type'], errors='coerce')
df['following_company_page'] = pd.to_numeric(df['following_company_page'], errors='coerce')
df['working_flag'] = pd.to_numeric(df['working_flag'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  int64
#  2   Yearly_avg_view_on_travel_page                11760 non-null  float64
#  3   preferred_device                              11707 non-null  float64
#  4   total_likes_on_outstation_checkin_given       11760 non-null  float64
#  5   yearly_avg_Outstation_checkins                11760 non-null  float64
#  6   member_in_family                              11760 non-null  int64
#  7   preferred_location_type                       11729 non-null  float64
#  8   Yearly_avg_comment_on_travel_page             11760 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11657 non-null  float64
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  int64
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 1.5 MB

# %%
df.isnull().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                    0
# preferred_device                                 53
# total_likes_on_outstation_checkin_given           0
# yearly_avg_Outstation_checkins                    0
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page                 0
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %%
df['preferred_device'].isnull().sum()
# Out:
# 53

# %%
df['preferred_device'].fillna(df['preferred_device'].mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                    0
# preferred_device                                  0
# total_likes_on_outstation_checkin_given           0
# yearly_avg_Outstation_checkins                    0
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page                 0
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp_cat = SimpleImputer(missing_values=np.nan, strategy="most_frequent")

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df["preferred_location_type"] =  imputer.fit_transform(df[["preferred_location_type"]])

# %%
df['preferred_location_type'].isnull().sum()
# Out:
# 0

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df["following_company_page"] =  imputer.fit_transform(df[["following_company_page"]])

# %%
df['following_company_page'].isnull().sum()
# Out:
# 0

# %%
df['preferred_device'] = pd.to_numeric(df['preferred_device'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  int64
#  2   Yearly_avg_view_on_travel_page                11760 non-null  float64
#  3   preferred_device                              11707 non-null  float64
#  4   total_likes_on_outstation_checkin_given       11760 non-null  float64
#  5   yearly_avg_Outstation_checkins                11760 non-null  float64
#  6   member_in_family                              11760 non-null  int64
#  7   preferred_location_type                       11760 non-null  float64
#  8   Yearly_avg_comment_on_travel_page             11760 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11760 non-null  float64
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  int64
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 1.5 MB

# %%
df.isnull().sum()
# Out:
# UserID                                           0
# Taken_product                                    0
# Yearly_avg_view_on_travel_page                   0
# preferred_device                                53
# total_likes_on_outstation_checkin_given          0
# yearly_avg_Outstation_checkins                   0
# member_in_family                                 0
# preferred_location_type                          0
# Yearly_avg_comment_on_travel_page                0
# total_likes_on_outofstation_checkin_received     0
# week_since_last_outstation_checkin               0
# following_company_page                           0
# montly_avg_comment_on_company_page               0
# working_flag                                     0
# travelling_network_rating                        0
# Adult_flag                                       0
# Daily_Avg_mins_spend_on_traveling_page           0
# dtype: int64

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df["preferred_device"] =  imputer.fit_transform(df[["preferred_device"]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  int64
#  2   Yearly_avg_view_on_travel_page                11760 non-null  float64
#  3   preferred_device                              11760 non-null  float64
#  4   total_likes_on_outstation_checkin_given       11760 non-null  float64
#  5   yearly_avg_Outstation_checkins                11760 non-null  float64
#  6   member_in_family                              11760 non-null  int64
#  7   preferred_location_type                       11760 non-null  float64
#  8   Yearly_avg_comment_on_travel_page             11760 non-null  float64
#  9   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  10  week_since_last_outstation_checkin            11760 non-null  int64
#  11  following_company_page                        11760 non-null  float64
#  12  montly_avg_comment_on_company_page            11760 non-null  int64
#  13  working_flag                                  11760 non-null  int64
#  14  travelling_network_rating                     11760 non-null  int64
#  15  Adult_flag                                    11760 non-null  int64
#  16  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 1.5 MB

# %%
df.isnull().sum()
# Out:
# UserID                                          0
# Taken_product                                   0
# Yearly_avg_view_on_travel_page                  0
# preferred_device                                0
# total_likes_on_outstation_checkin_given         0
# yearly_avg_Outstation_checkins                  0
# member_in_family                                0
# preferred_location_type                         0
# Yearly_avg_comment_on_travel_page               0
# total_likes_on_outofstation_checkin_received    0
# week_since_last_outstation_checkin              0
# following_company_page                          0
# montly_avg_comment_on_company_page              0
# working_flag                                    0
# travelling_network_rating                       0
# Adult_flag                                      0
# Daily_Avg_mins_spend_on_traveling_page          0
# dtype: int64

# %%
df.skew()
# Out:
# UserID                                          0.000000
# Taken_product                                   1.842719
# Yearly_avg_view_on_travel_page                  0.446136
# preferred_device                               -2.778436
# total_likes_on_outstation_checkin_given         0.498413
# yearly_avg_Outstation_checkins                  0.977806
# member_in_family                                0.001205
# preferred_location_type                         0.486200
# Yearly_avg_comment_on_travel_page               4.910947
# total_likes_on_outofstation_checkin_received    1.368578
# week_since_last_outstation_checkin              0.915334
# following_company_page                          0.978111
# montly_avg_comment_on_company_page              7.684150
# working_flag                                    1.920166
# travelling_network_rating                      -0.302557
# Adult_flag                                      0.968115
# Daily_Avg_mins_spend_on_traveling_page          4.480682
# dtype: float64

# %%
df.head()
# Out:
#     UserID  Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0  1000001              1                           307.0               1.0
# 1  1000002              0                           367.0               1.0
# 2  1000003              1                           277.0               1.0
# 3  1000004              0                           247.0               1.0
# 4  1000005              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                          5993
# 1                                          5130
# 2                                          2090
# 3                                          2909
# 4                                          3468
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                  11             0
# 1                                  23             1
# 2                                  15             0
# 3                                  11             0
# 4                                  12             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page
# 0                                       8
# 1                                      10
# 2                                       7
# 3                                       8
# 4                                       6

# %%
df.drop(['UserID'], axis=1, inplace = True)

# %%
df.head()
# Out:
#    Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0              1                           307.0               1.0
# 1              0                           367.0               1.0
# 2              1                           277.0               1.0
# 3              0                           247.0               1.0
# 4              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                          5993
# 1                                          5130
# 2                                          2090
# 3                                          2909
# 4                                          3468
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                  11             0
# 1                                  23             1
# 2                                  15             0
# 3                                  11             0
# 4                                  12             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page
# 0                                       8
# 1                                      10
# 2                                       7
# 3                                       8
# 4                                       6

# %% [markdown]
# ### Splitting the data frame

# %%
df1_laptop = df[df['preferred_device'] <= 0]

# %%
df1_laptop.head()
# Out:
#       Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 5881              0                           379.0               0.0
# 5883              0                           255.0               0.0
# 5885              0                           250.0               0.0
# 5888              0                           295.0               0.0
# 5906              1                           250.0               0.0
#
#       total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 5881                                   9776.0                             8.0
# 5883                                  48725.0                             3.0
# 5885                                  35184.0                             2.0
# 5888                                   7572.0                            23.0
# 5906                                  39379.0                            16.0
#
#       member_in_family  preferred_location_type  \
# 5881                 1                      0.0
# 5883                 4                      0.0
# 5885                 2                      0.0
# 5888                 3                      0.0
# 5906                 1                      0.0
#
#       Yearly_avg_comment_on_travel_page  \
# 5881                               64.0
# 5883                               59.0
# 5885                               84.0
# 5888                               48.0
# 5906                               80.0
#
#       total_likes_on_outofstation_checkin_received  \
# 5881                                          5142
# 5883                                          2913
# 5885                                          3074
# 5888                                          9532
# 5906                                          3926
#
#       week_since_last_outstation_checkin  following_company_page  \
# 5881                                   1                     0.0
# 5883                                   1                     1.0
# 5885                                   0                     0.0
# 5888                                   0                     0.0
# 5906                                   1                     1.0
#
#       montly_avg_comment_on_company_page  working_flag  \
# 5881                                  33             1
# 5883                                  19             0
# 5885                                  23             0
# 5888                                  33             1
# 5906                                  33             1
#
#       travelling_network_rating  Adult_flag  \
# 5881                          4           1
# 5883                          3           0
# 5885                          3           0
# 5888                          2           0
# 5906                          2           0
#
#       Daily_Avg_mins_spend_on_traveling_page
# 5881                                      10
# 5883                                       8
# 5885                                       8
# 5888                                      10
# 5906                                      10

# %%
df2_mobile = df[df['preferred_device'] >= 1]

# %%
df2_mobile.head()
# Out:
#    Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0              1                           307.0               1.0
# 1              0                           367.0               1.0
# 2              1                           277.0               1.0
# 3              0                           247.0               1.0
# 4              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                          5993
# 1                                          5130
# 2                                          2090
# 3                                          2909
# 4                                          3468
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                  11             0
# 1                                  23             1
# 2                                  15             0
# 3                                  11             0
# 4                                  12             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page
# 0                                       8
# 1                                      10
# 2                                       7
# 3                                       8
# 4                                       6

# %%
df1_laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 1108 non-null   int64
#  1   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  2   preferred_device                              1108 non-null   float64
#  3   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  4   yearly_avg_Outstation_checkins                1108 non-null   float64
#  5   member_in_family                              1108 non-null   int64
#  6   preferred_location_type                       1108 non-null   float64
#  7   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  8   total_likes_on_outofstation_checkin_received  1108 non-null   int64
#  9   week_since_last_outstation_checkin            1108 non-null   int64
#  10  following_company_page                        1108 non-null   float64
#  11  montly_avg_comment_on_company_page            1108 non-null   int64
#  12  working_flag                                  1108 non-null   int64
#  13  travelling_network_rating                     1108 non-null   int64
#  14  Adult_flag                                    1108 non-null   int64
#  15  Daily_Avg_mins_spend_on_traveling_page        1108 non-null   int64
# dtypes: float64(7), int64(9)
# memory usage: 147.2 KB

# %% [markdown]
# ### Feature selection using RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

# %%
x= df.drop('Taken_product', axis=1)
y= df['Taken_product']

# %% [markdown]
# #### RFE with decision tree

# %%
rfe = RFE (estimator= DecisionTreeClassifier(), n_features_to_select=10)
rfe.fit(x,y)
# Out:
# RFE(estimator=DecisionTreeClassifier(), n_features_to_select=10)

# %%
for i, col in zip(range(x.shape[1]), x.columns):
    print(f"{col} selected={rfe.support_[i]} rank={rfe.ranking_[i]}")
# Out:
# Yearly_avg_view_on_travel_page selected=True rank=1
# preferred_device selected=False rank=6
# total_likes_on_outstation_checkin_given selected=True rank=1
# yearly_avg_Outstation_checkins selected=True rank=1
# member_in_family selected=True rank=1
# preferred_location_type selected=False rank=3
# Yearly_avg_comment_on_travel_page selected=True rank=1
# total_likes_on_outofstation_checkin_received selected=True rank=1
# week_since_last_outstation_checkin selected=True rank=1
# following_company_page selected=True rank=1
# montly_avg_comment_on_company_page selected=False rank=5
# working_flag selected=False rank=4
# travelling_network_rating selected=True rank=1
# Adult_flag selected=True rank=1
# Daily_Avg_mins_spend_on_traveling_page selected=False rank=2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,train_size=0.70, random_state=1)

# %%
select = RFE(DecisionTreeClassifier(random_state=1), n_features_to_select=10)
select.fit(x_train, y_train)
x_train_selected = select.transform(x_train)

print("x_train.shape: {}".format(x_train.shape))
print("x_train_selected.shape: {}".format(x_train_selected.shape))
# Out:
# x_train.shape: (8232, 15)
# x_train_selected.shape: (8232, 10)

# %%
x_test_selected = select.transform(x_test)

rfe.fit(x_train, y_train)
print ('Score with all features: {:,.3f}'.format(rfe.score(x_test,y_test)))

rfe.fit(x_train_selected, y_train)
print ('Score with selected features: {:,.3f}'.format(rfe.score(x_test_selected,y_test)))
# Out:
# Score with all features: 0.989
# Score with selected features: 0.994

# %% [markdown]
# #### RFE with Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
rfe = RFE (estimator= RandomForestClassifier(), n_features_to_select=10)
rfe.fit(x,y)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
for i, col in zip(range(x.shape[1]), x.columns):
    print(f"{col} selected={rfe.support_[i]} rank={rfe.ranking_[i]}")
# Out:
# Yearly_avg_view_on_travel_page selected=True rank=1
# preferred_device selected=False rank=6
# total_likes_on_outstation_checkin_given selected=True rank=1
# yearly_avg_Outstation_checkins selected=True rank=1
# member_in_family selected=False rank=2
# preferred_location_type selected=False rank=3
# Yearly_avg_comment_on_travel_page selected=True rank=1
# total_likes_on_outofstation_checkin_received selected=True rank=1
# week_since_last_outstation_checkin selected=True rank=1
# following_company_page selected=True rank=1
# montly_avg_comment_on_company_page selected=False rank=4
# working_flag selected=False rank=5
# travelling_network_rating selected=True rank=1
# Adult_flag selected=True rank=1
# Daily_Avg_mins_spend_on_traveling_page selected=True rank=1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,train_size=0.70, random_state=1)

# %%
select = RFE(RandomForestClassifier(n_estimators=50, random_state=1), n_features_to_select=10)
select.fit(x_train, y_train)
x_train_selected = select.transform(x_train)

print("x_train.shape: {}".format(x_train.shape))
print("x_train_selected.shape: {}".format(x_train_selected.shape))
# Out:
# x_train.shape: (8232, 15)
# x_train_selected.shape: (8232, 10)

# %%
x_test_selected = select.transform(x_test)

rfe.fit(x_train, y_train)
print ('Score with all features: {:,.3f}'.format(rfe.score(x_test,y_test)))

rfe.fit(x_train_selected, y_train)
print ('Score with selected features: {:,.3f}'.format(rfe.score(x_test_selected,y_test)))
# Out:
# Score with all features: 0.987
# Score with selected features: 0.988

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 11760 non-null  int64
#  1   Yearly_avg_view_on_travel_page                11760 non-null  float64
#  2   preferred_device                              11760 non-null  float64
#  3   total_likes_on_outstation_checkin_given       11760 non-null  float64
#  4   yearly_avg_Outstation_checkins                11760 non-null  float64
#  5   member_in_family                              11760 non-null  int64
#  6   preferred_location_type                       11760 non-null  float64
#  7   Yearly_avg_comment_on_travel_page             11760 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  9   week_since_last_outstation_checkin            11760 non-null  int64
#  10  following_company_page                        11760 non-null  float64
#  11  montly_avg_comment_on_company_page            11760 non-null  int64
#  12  working_flag                                  11760 non-null  int64
#  13  travelling_network_rating                     11760 non-null  int64
#  14  Adult_flag                                    11760 non-null  int64
#  15  Daily_Avg_mins_spend_on_traveling_page        11760 non-null  int64
# dtypes: float64(7), int64(9)
# memory usage: 1.4 MB

# %%
df['Taken_product'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Yearly_avg_view_on_travel_page'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['preferred_device'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.set()
sns.set_palette(palette='tab10')

# %%
sns.displot(df, x="preferred_device", kind="kde", hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="member_in_family", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="preferred_location_type", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="following_company_page", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="working_flag", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="Adult_flag", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
sns.displot(df, x="week_since_last_outstation_checkin", kind='kde', hue = "Taken_product" , fill = True)
plt.show()

# %%
fig, axes = plt.subplots(nrows=3,ncols=2)
fig.set_size_inches(15, 18)

a = sns.distplot(df['Yearly_avg_view_on_travel_page'] , ax=axes[0][0])
a.set_title("Average yearly views on any travel related page by user",fontsize=10)
a = sns.boxplot(df['Yearly_avg_view_on_travel_page'] , orient = "v" , ax=axes[0][1])
a.set_title("Average yearly views on any travel related page by user",fontsize=10)
a = sns.distplot(df['total_likes_on_outstation_checkin_given'] , ax=axes[1][0])
a.set_title("Total number of likes given by a user on out of station checkings in last year",fontsize=10)
a = sns.boxplot(df['total_likes_on_outstation_checkin_given'] , orient = "v" , ax=axes[1][1])
a.set_title("Total number of likes given by a user on out of station checkings in last year",fontsize=10)
a = sns.distplot(df['yearly_avg_Outstation_checkins'] , ax=axes[2][0])
a.set_title("Average number of out of station check-in done by user",fontsize=10)
a = sns.boxplot(df['yearly_avg_Outstation_checkins'] , orient = "v" , ax=axes[2][1])
a.set_title("Average number of out of station check-in done by user",fontsize=10)
plt.show()

# %%
fig, axes = plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(17, 24)
a = sns.distplot(df['Yearly_avg_comment_on_travel_page'] , ax=axes[0][0])
a.set_title("Average yearly comments on any travel related page by user",fontsize=10)
a = sns.boxplot(df['Yearly_avg_comment_on_travel_page'] , orient = "v" , ax=axes[0][1])
a.set_title("Average yearly comments on any travel related page by user",fontsize=10)
a = sns.distplot(df['total_likes_on_outofstation_checkin_received'] , ax=axes[1][0])
a.set_title("Total number of likes received by a user on out of station checkings in last year",fontsize=10)
a = sns.boxplot(df['total_likes_on_outofstation_checkin_received'] , orient = "v" , ax=axes[1][1])
a.set_title("Total number of likes received by a user on out of station checkings in last year",fontsize=10)
a = sns.distplot(df['montly_avg_comment_on_company_page'] , ax=axes[2][0])
a.set_title("Average monthly comments on company page by user",fontsize=10)
a = sns.boxplot(df['montly_avg_comment_on_company_page'] , orient = "v" , ax=axes[2][1])
a.set_title("Average monthly comments on company page by user",fontsize=10)
a = sns.distplot(df['Daily_Avg_mins_spend_on_traveling_page'] , ax=axes[3][0])
a.set_title("Average time spend on the company page by user on daily basis",fontsize=10)
a = sns.boxplot(df['Daily_Avg_mins_spend_on_traveling_page'] , orient = "v" , ax=axes[3][1])
a.set_title("Average time spend on the company page by user on daily basis",fontsize=10)
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
corr = df.corr(method='pearson')
df.corr()
# Out:
#                                                 UserID  Taken_product  \
# UserID                                        1.000000      -0.001296
# Taken_product                                -0.001296       1.000000
# Yearly_avg_view_on_travel_page                0.084624      -0.149868
# preferred_device                             -0.277996      -0.077393
# total_likes_on_outstation_checkin_given      -0.011820      -0.054193
# yearly_avg_Outstation_checkins                0.105049       0.075805
# member_in_family                             -0.000913      -0.032282
# preferred_location_type                      -0.200755       0.024591
# Yearly_avg_comment_on_travel_page             0.227830      -0.005465
# total_likes_on_outofstation_checkin_received  0.001199      -0.159824
# week_since_last_outstation_checkin            0.085019       0.044725
# following_company_page                       -0.003099       0.245823
# montly_avg_comment_on_company_page            0.046861       0.000611
# working_flag                                 -0.002584       0.002889
# travelling_network_rating                    -0.008707      -0.045872
# Adult_flag                                    0.007807      -0.137145
# Daily_Avg_mins_spend_on_traveling_page        0.115261      -0.143220
#
#                                               Yearly_avg_view_on_travel_page  \
# UserID                                                              0.084624
# Taken_product                                                      -0.149868
# Yearly_avg_view_on_travel_page                                      1.000000
# preferred_device                                                   -0.008530
# total_likes_on_outstation_checkin_given                             0.010511
# yearly_avg_Outstation_checkins                                      0.008728
# member_in_family                                                    0.191293
# preferred_location_type                                            -0.042607
# Yearly_avg_comment_on_travel_page                                   0.041777
# total_likes_on_outofstation_checkin_received                        0.484846
# week_since_last_outstation_checkin                                  0.278970
# following_company_page                                              0.028490
# montly_avg_comment_on_company_page                                 -0.009498
# working_flag                                                        0.005257
# travelling_network_rating                                           0.056211
# Adult_flag                                                          0.036837
# Daily_Avg_mins_spend_on_traveling_page                              0.580170
#
#                                               preferred_device  \
# UserID                                               -0.277996
# Taken_product                                        -0.077393
# Yearly_avg_view_on_travel_page                       -0.008530
# preferred_device                                      1.000000
# total_likes_on_outstation_checkin_given               0.008790
# yearly_avg_Outstation_checkins                       -0.040091
# member_in_family                                      0.007844
# preferred_location_type                               0.096584
# Yearly_avg_comment_on_travel_page                    -0.036343
# total_likes_on_outofstation_checkin_received          0.020965
# week_since_last_outstation_checkin                    0.025611
# following_company_page                               -0.020257
# montly_avg_comment_on_company_page                    0.015374
# working_flag                                         -0.010640
# travelling_network_rating                            -0.019094
# Adult_flag                                            0.011123
# Daily_Avg_mins_spend_on_traveling_page                0.007064
#
#                                               total_likes_on_outstation_checkin_given  \
# UserID                                                                      -0.011820
# Taken_product                                                               -0.054193
# Yearly_avg_view_on_travel_page                                               0.010511
# preferred_device                                                             0.008790
# total_likes_on_outstation_checkin_given                                      1.000000
# yearly_avg_Outstation_checkins                                               0.006165
# member_in_family                                                            -0.012493
# preferred_location_type                                                      0.004174
# Yearly_avg_comment_on_travel_page                                            0.011995
# total_likes_on_outofstation_checkin_received                                 0.012275
# week_since_last_outstation_checkin                                           0.034838
# following_company_page                                                       0.013421
# montly_avg_comment_on_company_page                                           0.012437
# working_flag                                                                -0.000290
# travelling_network_rating                                                    0.010277
# Adult_flag                                                                   0.039411
# Daily_Avg_mins_spend_on_traveling_page                                       0.008914
#
#                                               yearly_avg_Outstation_checkins  \
# UserID                                                              0.105049
# Taken_product                                                       0.075805
# Yearly_avg_view_on_travel_page                                      0.008728
# preferred_device                                                   -0.040091
# total_likes_on_outstation_checkin_given                             0.006165
# yearly_avg_Outstation_checkins                                      1.000000
# member_in_family                                                    0.016987
# preferred_location_type                                            -0.018468
# Yearly_avg_comment_on_travel_page                                   0.046814
# total_likes_on_outofstation_checkin_received                       -0.012094
# week_since_last_outstation_checkin                                 -0.033420
# following_company_page                                              0.027120
# montly_avg_comment_on_company_page                                 -0.001656
# working_flag                                                        0.023850
# travelling_network_rating                                           0.004449
# Adult_flag                                                          0.047866
# Daily_Avg_mins_spend_on_traveling_page                              0.006730
#
#                                               member_in_family  \
# UserID                                               -0.000913
# Taken_product                                        -0.032282
# Yearly_avg_view_on_travel_page                        0.191293
# preferred_device                                      0.007844
# total_likes_on_outstation_checkin_given              -0.012493
# yearly_avg_Outstation_checkins                        0.016987
# member_in_family                                      1.000000
# preferred_location_type                              -0.004214
# Yearly_avg_comment_on_travel_page                     0.006398
# total_likes_on_outofstation_checkin_received          0.093035
# week_since_last_outstation_checkin                    0.111187
# following_company_page                               -0.018246
# montly_avg_comment_on_company_page                   -0.008773
# working_flag                                         -0.025449
# travelling_network_rating                            -0.011534
# Adult_flag                                            0.017422
# Daily_Avg_mins_spend_on_traveling_page                0.122344
#
#                                               preferred_location_type  \
# UserID                                                      -0.200755
# Taken_product                                                0.024591
# Yearly_avg_view_on_travel_page                              -0.042607
# preferred_device                                             0.096584
# total_likes_on_outstation_checkin_given                      0.004174
# yearly_avg_Outstation_checkins                              -0.018468
# member_in_family                                            -0.004214
# preferred_location_type                                      1.000000
# Yearly_avg_comment_on_travel_page                           -0.070847
# total_likes_on_outofstation_checkin_received                -0.005828
# week_since_last_outstation_checkin                          -0.001434
# following_company_page                                       0.013425
# montly_avg_comment_on_company_page                           0.007433
# working_flag                                                -0.006210
# travelling_network_rating                                    0.010910
# Adult_flag                                                   0.001213
# Daily_Avg_mins_spend_on_traveling_page                      -0.000964
#
#                                               Yearly_avg_comment_on_travel_page  \
# UserID                                                                 0.227830
# Taken_product                                                         -0.005465
# Yearly_avg_view_on_travel_page                                         0.041777
# preferred_device                                                      -0.036343
# total_likes_on_outstation_checkin_given                                0.011995
# yearly_avg_Outstation_checkins                                         0.046814
# member_in_family                                                       0.006398
# preferred_location_type                                               -0.070847
# Yearly_avg_comment_on_travel_page                                      1.000000
# total_likes_on_outofstation_checkin_received                          -0.013858
# week_since_last_outstation_checkin                                     0.059039
# following_company_page                                                -0.008975
# montly_avg_comment_on_company_page                                     0.019161
# working_flag                                                          -0.004871
# travelling_network_rating                                              0.007093
# Adult_flag                                                             0.043945
# Daily_Avg_mins_spend_on_traveling_page                                 0.059993
#
#                                               total_likes_on_outofstation_checkin_received  \
# UserID                                                                            0.001199
# Taken_product                                                                    -0.159824
# Yearly_avg_view_on_travel_page                                                    0.484846
# preferred_device                                                                  0.020965
# total_likes_on_outstation_checkin_given                                           0.012275
# yearly_avg_Outstation_checkins                                                   -0.012094
# member_in_family                                                                  0.093035
# preferred_location_type                                                          -0.005828
# Yearly_avg_comment_on_travel_page                                                -0.013858
# total_likes_on_outofstation_checkin_received                                      1.000000
# week_since_last_outstation_checkin                                                0.144058
# following_company_page                                                            0.007272
# montly_avg_comment_on_company_page                                               -0.005137
# working_flag                                                                     -0.017088
# travelling_network_rating                                                         0.025858
# Adult_flag                                                                        0.005418
# Daily_Avg_mins_spend_on_traveling_page                                            0.673410
#
#                                               week_since_last_outstation_checkin  \
# UserID                                                                  0.085019
# Taken_product                                                           0.044725
# Yearly_avg_view_on_travel_page                                          0.278970
# preferred_device                                                        0.025611
# total_likes_on_outstation_checkin_given                                 0.034838
# yearly_avg_Outstation_checkins                                         -0.033420
# member_in_family                                                        0.111187
# preferred_location_type                                                -0.001434
# Yearly_avg_comment_on_travel_page                                       0.059039
# total_likes_on_outofstation_checkin_received                            0.144058
# week_since_last_outstation_checkin                                      1.000000
# following_company_page                                                 -0.018883
# montly_avg_comment_on_company_page                                      0.031935
# working_flag                                                           -0.009376
# travelling_network_rating                                               0.051027
# Adult_flag                                                              0.026155
# Daily_Avg_mins_spend_on_traveling_page                                  0.249776
#
#                                               following_company_page  \
# UserID                                                     -0.003099
# Taken_product                                               0.245823
# Yearly_avg_view_on_travel_page                              0.028490
# preferred_device                                           -0.020257
# total_likes_on_outstation_checkin_given                     0.013421
# yearly_avg_Outstation_checkins                              0.027120
# member_in_family                                           -0.018246
# preferred_location_type                                     0.013425
# Yearly_avg_comment_on_travel_page                          -0.008975
# total_likes_on_outofstation_checkin_received                0.007272
# week_since_last_outstation_checkin                         -0.018883
# following_company_page                                      1.000000
# montly_avg_comment_on_company_page                          0.004300
# working_flag                                                0.004082
# travelling_network_rating                                   0.049474
# Adult_flag                                                 -0.000200
# Daily_Avg_mins_spend_on_traveling_page                      0.007623
#
#                                               montly_avg_comment_on_company_page  \
# UserID                                                                  0.046861
# Taken_product                                                           0.000611
# Yearly_avg_view_on_travel_page                                         -0.009498
# preferred_device                                                        0.015374
# total_likes_on_outstation_checkin_given                                 0.012437
# yearly_avg_Outstation_checkins                                         -0.001656
# member_in_family                                                       -0.008773
# preferred_location_type                                                 0.007433
# Yearly_avg_comment_on_travel_page                                       0.019161
# total_likes_on_outofstation_checkin_received                           -0.005137
# week_since_last_outstation_checkin                                      0.031935
# following_company_page                                                  0.004300
# montly_avg_comment_on_company_page                                      1.000000
# working_flag                                                            0.306742
# travelling_network_rating                                              -0.020538
# Adult_flag                                                             -0.011738
# Daily_Avg_mins_spend_on_traveling_page                                  0.054308
#
#                                               working_flag  \
# UserID                                           -0.002584
# Taken_product                                     0.002889
# Yearly_avg_view_on_travel_page                    0.005257
# preferred_device                                 -0.010640
# total_likes_on_outstation_checkin_given          -0.000290
# yearly_avg_Outstation_checkins                    0.023850
# member_in_family                                 -0.025449
# preferred_location_type                          -0.006210
# Yearly_avg_comment_on_travel_page                -0.004871
# total_likes_on_outofstation_checkin_received     -0.017088
# week_since_last_outstation_checkin               -0.009376
# following_company_page                            0.004082
# montly_avg_comment_on_company_page                0.306742
# working_flag                                      1.000000
# travelling_network_rating                        -0.031351
# Adult_flag                                        0.003506
# Daily_Avg_mins_spend_on_traveling_page            0.003589
#
#                                               travelling_network_rating  \
# UserID                                                        -0.008707
# Taken_product                                                 -0.045872
# Yearly_avg_view_on_travel_page                                 0.056211
# preferred_device                                              -0.019094
# total_likes_on_outstation_checkin_given                        0.010277
# yearly_avg_Outstation_checkins                                 0.004449
# member_in_family                                              -0.011534
# preferred_location_type                                        0.010910
# Yearly_avg_comment_on_travel_page                              0.007093
# total_likes_on_outofstation_checkin_received                   0.025858
# week_since_last_outstation_checkin                             0.051027
# following_company_page                                         0.049474
# montly_avg_comment_on_company_page                            -0.020538
# working_flag                                                  -0.031351
# travelling_network_rating                                      1.000000
# Adult_flag                                                    -0.045952
# Daily_Avg_mins_spend_on_traveling_page                         0.019657
#
#                                               Adult_flag  \
# UserID                                          0.007807
# Taken_product                                  -0.137145
# Yearly_avg_view_on_travel_page                  0.036837
# preferred_device                                0.011123
# total_likes_on_outstation_checkin_given         0.039411
# yearly_avg_Outstation_checkins                  0.047866
# member_in_family                                0.017422
# preferred_location_type                         0.001213
# Yearly_avg_comment_on_travel_page               0.043945
# total_likes_on_outofstation_checkin_received    0.005418
# week_since_last_outstation_checkin              0.026155
# following_company_page                         -0.000200
# montly_avg_comment_on_company_page             -0.011738
# working_flag                                    0.003506
# travelling_network_rating                      -0.045952
# Adult_flag                                      1.000000
# Daily_Avg_mins_spend_on_traveling_page          0.007775
#
#                                               Daily_Avg_mins_spend_on_traveling_page
# UserID                                                                      0.115261
# Taken_product                                                              -0.143220
# Yearly_avg_view_on_travel_page                                              0.580170
# preferred_device                                                            0.007064
# total_likes_on_outstation_checkin_given                                     0.008914
# yearly_avg_Outstation_checkins                                              0.006730
# member_in_family                                                            0.122344
# preferred_location_type                                                    -0.000964
# Yearly_avg_comment_on_travel_page                                           0.059993
# total_likes_on_outofstation_checkin_received                                0.673410
# week_since_last_outstation_checkin                                          0.249776
# following_company_page                                                      0.007623
# montly_avg_comment_on_company_page                                          0.054308
# working_flag                                                                0.003589
# travelling_network_rating                                                   0.019657
# Adult_flag                                                                  0.007775
# Daily_Avg_mins_spend_on_traveling_page                                      1.000000

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool)) 
fig = plt.subplots(figsize=(29,19))
sns.heatmap(df.corr(), annot=True,fmt='.2f',mask=mask, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(50,35))
sns.pairplot(df, hue ='Taken_product',corner=True)  
plt.show()

# %% [markdown]
# ### Outlier Treatment

# %%
Cont=['Yearly_avg_view_on_travel_page', 'total_likes_on_outstation_checkin_given',
      'yearly_avg_Outstation_checkins','Yearly_avg_comment_on_travel_page',
      'total_likes_on_outofstation_checkin_received','montly_avg_comment_on_company_page',
      'Daily_Avg_mins_spend_on_traveling_page']
plt.figure(figsize=(15,12))
df[Cont].boxplot(vert=0)
plt.title('With Outliers',fontsize=16)
plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df[Cont].columns:
    lr,ur=remove_outlier(df[column])
    df[column]=np.where(df[column]>ur,ur,df[column])
    df[column]=np.where(df[column]<lr,lr,df[column])

# %%
plt.figure(figsize=(15,12))
df[Cont].boxplot(vert=0)
plt.title('After Outlier Removal',fontsize=16)
plt.show()

# %% [markdown]
# ### KMeans Clusterring

# %%
df.head()
# Out:
#     UserID  Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0  1000001              1                           307.0               1.0
# 1  1000002              0                           367.0               1.0
# 2  1000003              1                           277.0               1.0
# 3  1000004              0                           247.0               1.0
# 4  1000005              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                        5993.0
# 1                                        5130.0
# 2                                        2090.0
# 3                                        2909.0
# 4                                        3468.0
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                11.0             0
# 1                                23.0             1
# 2                                15.0             0
# 3                                11.0             0
# 4                                12.0             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page
# 0                                     8.0
# 1                                    10.0
# 2                                     7.0
# 3                                     8.0
# 4                                     6.0

# %%
df_clust = df[['Taken_product','preferred_device', 'member_in_family', 'preferred_location_type', 'following_company_page', 'working_flag', 'travelling_network_rating','Adult_flag']]

# %%
df_clust['Taken_product'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_clust = df_clust.apply(le.fit_transform)
df_clust.head()
# Out:
#    Taken_product  preferred_device  member_in_family  preferred_location_type  \
# 0              1                 1                 1                        3
# 1              0                 1                 0                        3
# 2              1                 1                 1                       10
# 3              0                 1                 3                        3
# 4              0                 1                 0                        7
#
#    following_company_page  working_flag  travelling_network_rating  Adult_flag
# 0                       1             0                          0           0
# 1                       0             1                          3           1
# 2                       1             0                          1           0
# 3                       1             0                          2           0
# 4                       0             0                          3           1

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = StandardScaler()

# %%
scaled_df = pd.DataFrame(X.fit_transform(df_clust))

# %%
scaled_df
# Out:
#               0         1         2         3         4         5         6  \
# 0      2.280906  0.297919 -0.893927 -0.449464  1.474774 -0.426230 -1.584178
# 1     -0.438422  0.297919 -1.868126 -0.449464 -0.625667  2.346151  1.191438
# 2      2.280906  0.297919 -0.893927  1.370320  1.474774 -0.426230 -0.658973
# 3     -0.438422  0.297919  1.054471 -0.449464  1.474774 -0.426230  0.266233
# 4     -0.438422  0.297919 -1.868126  0.590413 -0.625667 -0.426230  1.191438
# ...         ...       ...       ...       ...       ...       ...       ...
# 11755 -0.438422 -3.022958 -0.893927  0.330444 -0.625667 -0.426230  0.266233
# 11756 -0.438422  0.297919 -1.868126  0.330444 -0.625667 -0.426230 -1.584178
# 11757 -0.438422  0.297919  0.080272 -1.229371  1.474774  2.346151 -0.658973
# 11758 -0.438422 -3.022958  0.080272  0.330444 -0.625667 -0.426230  1.191438
# 11759 -0.438422  0.297919  0.080272  0.330444 -0.625667 -0.426230 -1.584178
#
#               7
# 0     -0.932014
# 1      0.241988
# 2     -0.932014
# 3     -0.932014
# 4      0.241988
# ...         ...
# 11755  0.241988
# 11756  0.241988
# 11757  0.241988
# 11758 -0.932014
# 11759 -0.932014
#
# [11760 rows x 8 columns]

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans(n_clusters = 2,random_state=1)

# %%
k_means.fit(scaled_df)
# Out:
# KMeans(n_clusters=2, random_state=1)

# %%
k_means = KMeans(n_clusters = 2,random_state=1)

# %%
k_means = KMeans(n_clusters =2,random_state=1)
k_means.fit(scaled_df)
labels = k_means.labels_

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silhouette_score(scaled_df,labels,random_state=1)
# Out:
# 0.2457646839945938

# %%
df["Clus_kmeans4"] = labels
df.head()
# Out:
#     UserID  Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0  1000001              1                           307.0               1.0
# 1  1000002              0                           367.0               1.0
# 2  1000003              1                           277.0               1.0
# 3  1000004              0                           247.0               1.0
# 4  1000005              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                        5993.0
# 1                                        5130.0
# 2                                        2090.0
# 3                                        2909.0
# 4                                        3468.0
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                11.0             0
# 1                                23.0             1
# 2                                15.0             0
# 3                                11.0             0
# 4                                12.0             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page  Clus_kmeans4
# 0                                     8.0             0
# 1                                    10.0             1
# 2                                     7.0             0
# 3                                     8.0             1
# 4                                     6.0             1

# %%
df.Clus_kmeans4.value_counts().sort_index()
# Out:
# 0    1896
# 1    9864
# Name: Clus_kmeans4, dtype: int64

# %%
df["Clus_kmeans4"] = labels
df.head()
# Out:
#     UserID  Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0  1000001              1                           307.0               1.0
# 1  1000002              0                           367.0               1.0
# 2  1000003              1                           277.0               1.0
# 3  1000004              0                           247.0               1.0
# 4  1000005              0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family  preferred_location_type  \
# 0                 2                      3.0
# 1                 1                      3.0
# 2                 2                     10.0
# 3                 4                      3.0
# 4                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# 4                               40.0
#
#    total_likes_on_outofstation_checkin_received  \
# 0                                        5993.0
# 1                                        5130.0
# 2                                        2090.0
# 3                                        2909.0
# 4                                        3468.0
#
#    week_since_last_outstation_checkin  following_company_page  \
# 0                                   8                     1.0
# 1                                   1                     0.0
# 2                                   6                     1.0
# 3                                   1                     1.0
# 4                                   9                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                11.0             0
# 1                                23.0             1
# 2                                15.0             0
# 3                                11.0             0
# 4                                12.0             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page  Clus_kmeans4
# 0                                     8.0             0
# 1                                    10.0             1
# 2                                     7.0             0
# 3                                     8.0             1
# 4                                     6.0             1

# %%
clus01 = df[df['Clus_kmeans4']==0]
clus02 = df[df['Clus_kmeans4']==1]

# %%
clus01['Taken_product'].value_counts()
# Out:
# 1    1896
# Name: Taken_product, dtype: int64

# %%
clus02['Taken_product'].value_counts()
# Out:
# 0    9864
# Name: Taken_product, dtype: int64

# %%
clus01['preferred_device'].value_counts()
# Out:
# 1.0    1610
# 0.0     276
# Name: preferred_device, dtype: int64

# %%
clus02['preferred_device'].value_counts()
# Out:
# 1.0    8989
# 0.0     832
# Name: preferred_device, dtype: int64

# %%
sns.countplot(df['Clus_kmeans4'])
plt.show()

# %%
sns.scatterplot(df['Yearly_avg_view_on_travel_page'], df['total_likes_on_outofstation_checkin_received'], hue=df['Clus_kmeans4'], palette='Set2')
# Out:
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page', ylabel='total_likes_on_outofstation_checkin_received'>

# %%
sns.scatterplot(df['preferred_device'], df['total_likes_on_outofstation_checkin_received'], hue=df['Clus_kmeans4'], palette='Set2')
# Out:
# <AxesSubplot:xlabel='preferred_device', ylabel='total_likes_on_outofstation_checkin_received'>

# %% [markdown]
# ##### Not much could be derived from clusterring

# %%
print(df.columns)
# Out:
# Index(['UserID', 'Taken_product', 'Yearly_avg_view_on_travel_page',
#        'preferred_device', 'yearly_avg_Outstation_checkins',
#        'member_in_family', 'preferred_location_type',
#        'Yearly_avg_comment_on_travel_page', 'following_company_page',
#        'montly_avg_comment_on_company_page', 'working_flag',
#        'travelling_network_rating', 'Adult_flag',
#        'Daily_Avg_mins_spend_on_traveling_page'],
#       dtype='object')

# %%
df.drop(['UserID'], axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Taken_product                           11760 non-null  int64
#  1   Yearly_avg_view_on_travel_page          11760 non-null  float64
#  2   preferred_device                        11760 non-null  float64
#  3   yearly_avg_Outstation_checkins          11760 non-null  float64
#  4   member_in_family                        11760 non-null  int64
#  5   preferred_location_type                 11760 non-null  float64
#  6   Yearly_avg_comment_on_travel_page       11760 non-null  float64
#  7   following_company_page                  11760 non-null  float64
#  8   montly_avg_comment_on_company_page      11760 non-null  int64
#  9   working_flag                            11760 non-null  int64
#  10  travelling_network_rating               11760 non-null  int64
#  11  Adult_flag                              11760 non-null  int64
#  12  Daily_Avg_mins_spend_on_traveling_page  11760 non-null  int64
# dtypes: float64(6), int64(7)
# memory usage: 1.2 MB

# %%
df.head()
# Out:
#    Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0              1                           307.0               1.0
# 1              0                           367.0               1.0
# 2              1                           277.0               1.0
# 3              0                           247.0               1.0
# 4              0                           202.0               1.0
#
#    yearly_avg_Outstation_checkins  member_in_family  preferred_location_type  \
# 0                             1.0                 2                      3.0
# 1                             1.0                 1                      3.0
# 2                             1.0                 2                     10.0
# 3                             1.0                 4                      3.0
# 4                             1.0                 1                      7.0
#
#    Yearly_avg_comment_on_travel_page  following_company_page  \
# 0                               94.0                     1.0
# 1                               61.0                     0.0
# 2                               92.0                     1.0
# 3                               56.0                     1.0
# 4                               40.0                     0.0
#
#    montly_avg_comment_on_company_page  working_flag  \
# 0                                  11             0
# 1                                  23             1
# 2                                  15             0
# 3                                  11             0
# 4                                  12             0
#
#    travelling_network_rating  Adult_flag  \
# 0                          1           0
# 1                          4           1
# 2                          2           0
# 3                          3           0
# 4                          4           1
#
#    Daily_Avg_mins_spend_on_traveling_page
# 0                                       8
# 1                                      10
# 2                                       7
# 3                                       8
# 4                                       6

# %%
import sklearn
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score,roc_curve
from collections import Counter
from sklearn.metrics import classification_report

# %% [markdown]
# ## Data split for df1_laptop dataset

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
X_train,X_test, y_train, y_test=train_test_split(X,y,train_size=0.70, random_state=1)

# %%
# Check the number of records
print('The number of records in the training dataset is', X_train.shape[0])
# Out:
# The number of records in the training dataset is 775

# %%
print('The number of records in the test dataset is', X_test.shape[0])
# Out:
# The number of records in the test dataset is 333

# %%
print(f"The training dataset has {sorted(Counter(y_train).items())[0][1]} records for the majority class and {sorted(Counter(y_train).items())[1][1]} records for the minority class.")
# Out:
# The training dataset has 594 records for the majority class and 181 records for the minority class.

# %%
X_train.head()
# Out:
#        Yearly_avg_view_on_travel_page  preferred_device  \
# 9404                            328.0               0.0
# 9788                            281.0               0.0
# 10215                           246.0               0.0
# 7916                            365.0               0.0
# 10024                           370.0               0.0
#
#        total_likes_on_outstation_checkin_given  \
# 9404                                   20006.0
# 9788                                   21306.0
# 10215                                  26433.0
# 7916                                   25177.0
# 10024                                  24832.0
#
#        yearly_avg_Outstation_checkins  member_in_family  \
# 9404                              8.0                 3
# 9788                              7.0                 3
# 10215                            26.0                 4
# 7916                             27.0                 2
# 10024                             7.0                 2
#
#        preferred_location_type  Yearly_avg_comment_on_travel_page  \
# 9404                       0.0                               81.0
# 9788                       1.0                               96.0
# 10215                      1.0                               86.0
# 7916                       0.0                               85.0
# 10024                      6.0                              113.0
#
#        total_likes_on_outofstation_checkin_received  \
# 9404                                          18493
# 9788                                           4691
# 10215                                          5685
# 7916                                           6404
# 10024                                          2718
#
#        week_since_last_outstation_checkin  following_company_page  \
# 9404                                    2                     0.0
# 9788                                    3                     0.0
# 10215                                   3                     1.0
# 7916                                    4                     1.0
# 10024                                   4                     1.0
#
#        montly_avg_comment_on_company_page  working_flag  \
# 9404                                   26             0
# 9788                                   35             0
# 10215                                  32             0
# 7916                                   24             0
# 10024                                  23             0
#
#        travelling_network_rating  Adult_flag  \
# 9404                           2           1
# 9788                           4           1
# 10215                          3           0
# 7916                           4           0
# 10024                          3           2
#
#        Daily_Avg_mins_spend_on_traveling_page
# 9404                                       34
# 9788                                       21
# 10215                                      17
# 7916                                        8
# 10024                                      26

# %%
X_train.isnull().sum()
# Out:
# Yearly_avg_view_on_travel_page                  0
# preferred_device                                0
# total_likes_on_outstation_checkin_given         0
# yearly_avg_Outstation_checkins                  0
# member_in_family                                0
# preferred_location_type                         0
# Yearly_avg_comment_on_travel_page               0
# total_likes_on_outofstation_checkin_received    0
# week_since_last_outstation_checkin              0
# following_company_page                          0
# montly_avg_comment_on_company_page              0
# working_flag                                    0
# travelling_network_rating                       0
# Adult_flag                                      0
# Daily_Avg_mins_spend_on_traveling_page          0
# dtype: int64

# %% [markdown]
# # Creating Models for Laptop users
#
#
# ##### Taking the best selected features from RFE

# %%
df_new = df[['Yearly_avg_view_on_travel_page','total_likes_on_outstation_checkin_given','yearly_avg_Outstation_checkins',
             'member_in_family', 'Yearly_avg_comment_on_travel_page','total_likes_on_outofstation_checkin_received',
             'week_since_last_outstation_checkin','following_company_page','travelling_network_rating','Adult_flag',
             'Taken_product', 'preferred_device']]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                11760 non-null  float64
#  1   total_likes_on_outstation_checkin_given       11760 non-null  float64
#  2   yearly_avg_Outstation_checkins                11760 non-null  float64
#  3   member_in_family                              11760 non-null  int64
#  4   Yearly_avg_comment_on_travel_page             11760 non-null  float64
#  5   total_likes_on_outofstation_checkin_received  11760 non-null  int64
#  6   week_since_last_outstation_checkin            11760 non-null  int64
#  7   following_company_page                        11760 non-null  float64
#  8   travelling_network_rating                     11760 non-null  int64
#  9   Adult_flag                                    11760 non-null  int64
#  10  Taken_product                                 11760 non-null  int64
#  11  preferred_device                              11760 non-null  float64
# dtypes: float64(6), int64(6)
# memory usage: 1.1 MB

# %% [markdown]
# ##### WE will devide the dataset into 2 dataframes one each for Laptop users and Mobile users

# %%
df1_laptop = df_new[df_new['preferred_device'] <= 0]

# %%
df1_laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  1   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  2   yearly_avg_Outstation_checkins                1108 non-null   float64
#  3   member_in_family                              1108 non-null   int64
#  4   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  5   total_likes_on_outofstation_checkin_received  1108 non-null   int64
#  6   week_since_last_outstation_checkin            1108 non-null   int64
#  7   following_company_page                        1108 non-null   float64
#  8   travelling_network_rating                     1108 non-null   int64
#  9   Adult_flag                                    1108 non-null   int64
#  10  Taken_product                                 1108 non-null   int64
#  11  preferred_device                              1108 non-null   float64
# dtypes: float64(6), int64(6)
# memory usage: 112.5 KB

# %%
df1_laptop.drop('preferred_device', axis=1, inplace=True)

# %%
df1_laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  1   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  2   yearly_avg_Outstation_checkins                1108 non-null   float64
#  3   member_in_family                              1108 non-null   int64
#  4   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  5   total_likes_on_outofstation_checkin_received  1108 non-null   int64
#  6   week_since_last_outstation_checkin            1108 non-null   int64
#  7   following_company_page                        1108 non-null   float64
#  8   travelling_network_rating                     1108 non-null   int64
#  9   Adult_flag                                    1108 non-null   int64
#  10  Taken_product                                 1108 non-null   int64
# dtypes: float64(5), int64(6)
# memory usage: 103.9 KB

# %%
df2_mobile = df_new[df_new['preferred_device'] >= 1]

# %%
df2_mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10652 entries, 0 to 11759
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                10652 non-null  float64
#  1   total_likes_on_outstation_checkin_given       10652 non-null  float64
#  2   yearly_avg_Outstation_checkins                10652 non-null  float64
#  3   member_in_family                              10652 non-null  int64
#  4   Yearly_avg_comment_on_travel_page             10652 non-null  float64
#  5   total_likes_on_outofstation_checkin_received  10652 non-null  int64
#  6   week_since_last_outstation_checkin            10652 non-null  int64
#  7   following_company_page                        10652 non-null  float64
#  8   travelling_network_rating                     10652 non-null  int64
#  9   Adult_flag                                    10652 non-null  int64
#  10  Taken_product                                 10652 non-null  int64
#  11  preferred_device                              10652 non-null  float64
# dtypes: float64(6), int64(6)
# memory usage: 1.1 MB

# %%
df2_mobile.drop('preferred_device', axis=1, inplace=True)

# %%
df2_mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10652 entries, 0 to 11759
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                10652 non-null  float64
#  1   total_likes_on_outstation_checkin_given       10652 non-null  float64
#  2   yearly_avg_Outstation_checkins                10652 non-null  float64
#  3   member_in_family                              10652 non-null  int64
#  4   Yearly_avg_comment_on_travel_page             10652 non-null  float64
#  5   total_likes_on_outofstation_checkin_received  10652 non-null  int64
#  6   week_since_last_outstation_checkin            10652 non-null  int64
#  7   following_company_page                        10652 non-null  float64
#  8   travelling_network_rating                     10652 non-null  int64
#  9   Adult_flag                                    10652 non-null  int64
#  10  Taken_product                                 10652 non-null  int64
# dtypes: float64(5), int64(6)
# memory usage: 998.6 KB

# %% [markdown]
# ### Build Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Image  
from sklearn import tree

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1)

# %%
dTree = DecisionTreeClassifier(criterion = 'gini', random_state=1)
dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
print(dTree.score(X_train, y_train))
print(dTree.score(X_test, y_test))
# Out:
# 1.0
# 0.975975975975976

# %%
train_char_label = ['No', 'Yes']
Credit_Tree_File = open('credit_tree.dot','w')
dot_data = tree.export_graphviz(dTree, out_file=Credit_Tree_File, feature_names = list(X_train), class_names = list(train_char_label))
Credit_Tree_File.close()

# %%
dTreeR = DecisionTreeClassifier(criterion = 'gini', max_depth = 3, random_state=1)
dTreeR.fit(X_train, y_train)
print(dTreeR.score(X_train, y_train))
print(dTreeR.score(X_test, y_test))
# Out:
# 0.8219354838709677
# 0.8108108108108109

# %% [markdown]
# ### Baseline Random Forest Model for unbalanced data for LAptop dataset

# %%
import sklearn
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score,roc_curve
from collections import Counter
from sklearn.metrics import classification_report

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
X_train,X_test, y_train, y_test=train_test_split(X,y,train_size=0.70, random_state=1)

# %%
# Check the number of records
print('The number of records in the training dataset is', X_train.shape[0])
# Out:
# The number of records in the training dataset is 775

# %%
print('The number of records in the test dataset is', X_test.shape[0])
# Out:
# The number of records in the test dataset is 333

# %%
print(f"The training dataset has {sorted(Counter(y_train).items())[0][1]} records for the majority class and {sorted(Counter(y_train).items())[1][1]} records for the minority class.")
# Out:
# The training dataset has 594 records for the majority class and 181 records for the minority class.

# %%
# To understand the differences of different random states affecting Out-of-Bag score
random_state=[0,23,42]
for i in random_state:
    rf=RandomForestClassifier(random_state=i,oob_score=True)
    rf.fit(X_train,y_train)
    print(rf.oob_score_)
# Out:
# 0.9754838709677419
# 0.9729032258064516
# 0.9767741935483871

# %%
rfcl = RandomForestClassifier(n_estimators = 100,max_features=6,random_state=0)
rfcl = rfcl.fit(X_train, y_train)

# %%
rfcl
# Out:
# RandomForestClassifier(max_features=6, random_state=0)

# %% [markdown]
# #### Predicting Train and Test data with the RF Model

# %%
ytrain_predict = rfcl.predict(X_train)
ytest_predict = rfcl.predict(X_test)

# %% [markdown]
# ##### Train Accuracy

# %%
rfcl.score(X_train,y_train)
# Out:
# 1.0

# %%
rfcl.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ##### Evaluating model performance with confusion matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
# Get the confusion matrix on the train data
confusion_matrix(y_train,ytrain_predict)
sns.heatmap(confusion_matrix(y_train,ytrain_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_train,ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       594
#            1       1.00      1.00      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
print('Accuracy', ((594+181)/(594+181)))
print('Sensitivity',((181/181))) #TP/Actual yes
print('Specificity',(594/594)) #TN/Actual no
print('Precision',(181/181)) #TP/Predicted yes
# Out:
# Accuracy 1.0
# Sensitivity 1.0
# Specificity 1.0
# Precision 1.0

# %%
from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(y_train,rfcl.predict_proba(X_train)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(y_train,rfcl.predict_proba(X_train)[:,1]))
# Out:
# Area under Curve is 1.0

# %% [markdown]
# #### Evaluating model performance on the test data

# %%
confusion_matrix(y_test,ytest_predict)
sns.heatmap(confusion_matrix(y_test,ytest_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       238
#            1       1.00      1.00      1.00        95
#
#     accuracy                           1.00       333
#    macro avg       1.00      1.00      1.00       333
# weighted avg       1.00      1.00      1.00       333

# %% [markdown]
# #### Test Accuracy

# %%
rfcl.score(X_test,y_test)
# Out:
# 1.0

# %%
#from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(y_test,rfcl.predict_proba(X_test)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(y_test,rfcl.predict_proba(X_test)[:,1]))
# Out:
# Area under Curve is 1.0

# %% [markdown]
# ## Baseline Random Forest Model for unbalanced data for Mobile dataset

# %%
X = df2_mobile.drop('Taken_product', axis=1)
y = df2_mobile['Taken_product']

# %%
X_train,X_test, y_train, y_test=train_test_split(X,y,train_size=0.70, random_state=1)

# %%
# Check the number of records
print('The number of records in the training dataset is', X_train.shape[0])
# Out:
# The number of records in the training dataset is 7456

# %%
print('The number of records in the test dataset is', X_test.shape[0])
# Out:
# The number of records in the test dataset is 3196

# %%
print(f"The training dataset has {sorted(Counter(y_train).items())[0][1]} records for the majority class and {sorted(Counter(y_train).items())[1][1]} records for the minority class.")
# Out:
# The training dataset has 6330 records for the majority class and 1126 records for the minority class.

# %%
# To understand the differences of different random states affecting Out-of-Bag score
random_state=[0,23,42]
for i in random_state:
    rf=RandomForestClassifier(random_state=i,oob_score=True)
    rf.fit(X_train,y_train)
    print(rf.oob_score_)
# Out:
# 0.9888680257510729
# 0.9877950643776824
# 0.987392703862661

# %%
rfcl = RandomForestClassifier(n_estimators = 100,max_features=6,random_state=0)
rfcl = rfcl.fit(X_train, y_train)

# %%
rfcl
# Out:
# RandomForestClassifier(max_features=6, random_state=0)

# %% [markdown]
# #### Predicting Train and Test data with the RF Model

# %%
ytrain_predict = rfcl.predict(X_train)
ytest_predict = rfcl.predict(X_test)

# %% [markdown]
# ##### Train Accuracy

# %%
rfcl.score(X_train,y_train)
# Out:
# 1.0

# %%
# Get the confusion matrix on the train data
confusion_matrix(y_train,ytrain_predict)
sns.heatmap(confusion_matrix(y_train,ytrain_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix RF')
plt.show()

print(classification_report(y_train,ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6330
#            1       1.00      1.00      1.00      1126
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456

# %%
from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(y_train,rfcl.predict_proba(X_train)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(y_train,rfcl.predict_proba(X_train)[:,1]))
# Out:
# Area under Curve is 1.0

# %%
confusion_matrix(y_test,ytest_predict)
sns.heatmap(confusion_matrix(y_test,ytest_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix RF')
plt.show()

print(classification_report(y_test,ytest_predict))

#from sklearn.metrics import roc_curve,roc_auc_score
rf_fpr, rf_tpr,_=roc_curve(y_test,rfcl.predict_proba(X_test)[:,1])
plt.figure(figsize=(12,7))
plt.plot(rf_fpr,rf_tpr, marker='x', label='Random Forest')
plt.plot(np.arange(0,1.1,0.1),np.arange(0,1.1,0.1))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
print('Area under Curve is', roc_auc_score(y_test,rfcl.predict_proba(X_test)[:,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2702
#            1       0.99      0.94      0.96       494
#
#     accuracy                           0.99      3196
#    macro avg       0.99      0.97      0.98      3196
# weighted avg       0.99      0.99      0.99      3196
# Area under Curve is 0.999177022868051

# %% [markdown]
# #### Test Accuracy

# %%
rfcl.score(X_test,y_test)
# Out:
# 0.9893617021276596

# %% [markdown]
# ### SMOTE Oversampling for Imbalanced Laptop Dataset

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote= smote.fit_resample(X_train, y_train)

print(sorted(Counter(y_train_smote).items()))
# Out:
# [(0, 594), (1, 594)]

# %% [markdown]
# ###### Now let’s run the same random forest model on the SMOTE dataset and check its performance.

# %%
rf = RandomForestClassifier()
smote_model = rf.fit(X_train_smote, y_train_smote)
smote_prediction = smote_model.predict(X_test)

print(classification_report(y_test, smote_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       238
#            1       0.99      1.00      0.99        95
#
#     accuracy                           1.00       333
#    macro avg       0.99      1.00      1.00       333
# weighted avg       1.00      1.00      1.00       333

# %% [markdown]
# ### SMOTE Oversampling for Imbalanced Mobile Dataset

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote= smote.fit_resample(X_train, y_train)

print(sorted(Counter(y_train_smote).items()))
# Out:
# [(0, 6330), (1, 6330)]

# %% [markdown]
# ###### Now let’s run the same random forest model on the SMOTE dataset and check its performance.

# %%
rf = RandomForestClassifier()
smote_model = rf.fit(X_train_smote, y_train_smote)
smote_prediction = smote_model.predict(X_test)

print(classification_report(y_test, smote_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2702
#            1       0.99      0.96      0.98       494
#
#     accuracy                           0.99      3196
#    macro avg       0.99      0.98      0.99      3196
# weighted avg       0.99      0.99      0.99      3196

# %% [markdown]
# ### Logistic Regression for Laptop dataset

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logistic_model = LogisticRegression()
Logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_predict=Logistic_model.predict(X_train)
Logistic_model_score=Logistic_model.score(X_train,y_train)
print(Logistic_model_score)
# Out:
# 0.7896774193548387

# %%
y_train_prob=Logistic_model.predict_proba(X_train)
pd.DataFrame(y_train_prob).head()
# Out:
#           0         1
# 0  0.983916  0.016084
# 1  0.738395  0.261605
# 2  0.551736  0.448264
# 3  0.712987  0.287013
# 4  0.698824  0.301176

# %%
y_train_predict=Logistic_model.predict(X_train)
Logistic_model_score=Logistic_model.score(X_train,y_train)
print(Logistic_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.7896774193548387
# [[581  13]
#  [150  31]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88       594
#            1       0.70      0.17      0.28       181
#
#     accuracy                           0.79       775
#    macro avg       0.75      0.57      0.58       775
# weighted avg       0.77      0.79      0.74       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# predict probabilities
probs = Logistic_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.754

# %%
y_test_predict=Logistic_model.predict(X_test)
Logistic_model_score=Logistic_model.score(X_test,y_test)
print(Logistic_model_score)
# Out:
# 0.7537537537537538

# %%
y_test_predict=Logistic_model.predict(X_test)
Logistic_model_score=Logistic_model.score(X_test,y_test)
print(Logistic_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.7537537537537538
# [[233   5]
#  [ 77  18]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85       238
#            1       0.78      0.19      0.31        95
#
#     accuracy                           0.75       333
#    macro avg       0.77      0.58      0.58       333
# weighted avg       0.76      0.75      0.69       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
probs_test = Logistic_model.predict_proba(X_test)

probs_test = probs_test[:, 1]

auc = roc_auc_score(y_test, probs_test)
print('AUC: %.3f' % auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs_test)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.792

# %% [markdown]
# ### Logistic Regression for Mobile dataset

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logistic_model = LogisticRegression()
Logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_predict=Logistic_model.predict(X_train)
Logistic_model_score=Logistic_model.score(X_train,y_train)
print(Logistic_model_score)
# Out:
# 0.8488465665236051

# %%
y_train_prob=Logistic_model.predict_proba(X_train)
pd.DataFrame(y_train_prob).head()
# Out:
#           0         1
# 0  0.718756  0.281244
# 1  0.932907  0.067093
# 2  0.859508  0.140492
# 3  0.908852  0.091148
# 4  0.959456  0.040544

# %%
y_train_predict=Logistic_model.predict(X_train)
Logistic_model_score=Logistic_model.score(X_train,y_train)
print(Logistic_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8488465665236051
# [[6318   12]
#  [1115   11]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      6330
#            1       0.48      0.01      0.02      1126
#
#     accuracy                           0.85      7456
#    macro avg       0.66      0.50      0.47      7456
# weighted avg       0.79      0.85      0.78      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %%
# predict probabilities
probs = Logistic_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.699

# %%
y_test_predict=Logistic_model.predict(X_test)
Logistic_model_score=Logistic_model.score(X_test,y_test)
print(Logistic_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8444931163954944
# [[2699    3]
#  [ 494    0]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2702
#            1       0.00      0.00      0.00       494
#
#     accuracy                           0.84      3196
#    macro avg       0.42      0.50      0.46      3196
# weighted avg       0.71      0.84      0.77      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %%
probs_test = Logistic_model.predict_proba(X_test)

probs_test = probs_test[:, 1]

auc = roc_auc_score(y_test, probs_test)
print('AUC: %.3f' % auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs_test)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.692

# %% [markdown]
# ### Modelling using Gridsearch for Logistic model for laptop dataset

# %%
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.817112 using {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.810472 (0.021035) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.777677 (0.026607) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.772880 (0.027832) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.810773 (0.020185) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.781592 (0.029824) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.773773 (0.027586) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.810172 (0.020306) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.777693 (0.032129) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.771046 (0.028161) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.814698 (0.019147) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.775880 (0.033194) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.773762 (0.024003) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.817112 (0.022889) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.782509 (0.028122) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.768946 (0.023626) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
Logistic2_model = LogisticRegression(solver='newton-cg',penalty='l2',verbose=True,n_jobs=2, C=0.01)
Logistic2_model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    1.4s finished
# LogisticRegression(C=0.01, n_jobs=2, solver='newton-cg', verbose=True)

# %%
y_train_predict=Logistic2_model.predict(X_train)
Logistic2_model_score=Logistic2_model.score(X_train,y_train)
print(Logistic2_model_score)
# Out:
# 0.8116129032258065

# %%
y_test_predict=Logistic2_model.predict(X_test)
Logistic2_model_score=Logistic2_model.score(X_test,y_test)
print(Logistic2_model_score)
# Out:
# 0.7867867867867868

# %%
y_train_predict=Logistic2_model.predict(X_train)
Logistic2_model_score=Logistic2_model.score(X_train,y_train)
print(Logistic2_model_score)
print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8116129032258065
# [[587   7]
#  [139  42]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89       594
#            1       0.86      0.23      0.37       181
#
#     accuracy                           0.81       775
#    macro avg       0.83      0.61      0.63       775
# weighted avg       0.82      0.81      0.77       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# predict probabilities
probs = Logistic2_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.774

# %%
y_test_predict=Logistic2_model.predict(X_test)
Logistic2_model_score=Logistic2_model.score(X_test,y_test)
print(Logistic2_model_score)
print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.7867867867867868
# [[236   2]
#  [ 69  26]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.99      0.87       238
#            1       0.93      0.27      0.42        95
#
#     accuracy                           0.79       333
#    macro avg       0.85      0.63      0.65       333
# weighted avg       0.82      0.79      0.74       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
probs_test = Logistic2_model.predict_proba(X_test)

probs_test = probs_test[:, 1]

auc = roc_auc_score(y_test, probs_test)
print('AUC: %.3f' % auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs_test)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.830

# %% [markdown]
# ### Modelling using Gridsearch for Logistic model for Mobile dataset

# %%
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.861247 using {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.861247 (0.004221) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.848260 (0.001486) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.848229 (0.000547) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.861216 (0.004149) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.847822 (0.001194) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.848385 (0.001379) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.861216 (0.004192) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.848135 (0.002605) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.848198 (0.000725) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.860684 (0.004107) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.847916 (0.001618) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.848229 (0.000807) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.857586 (0.003089) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.847885 (0.001179) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.848761 (0.002066) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
Logistic2_model = LogisticRegression(solver='newton-cg',penalty='l2',verbose=True,n_jobs=2, C=100)
Logistic2_model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    2.0s finished
# LogisticRegression(C=100, n_jobs=2, solver='newton-cg', verbose=True)

# %%
y_train_predict=Logistic2_model.predict(X_train)
Logistic2_model_score=Logistic2_model.score(X_train,y_train)
print(Logistic2_model_score)
# Out:
# 0.8599785407725322

# %%
y_train_predict=Logistic2_model.predict(X_train)
Logistic2_model_score=Logistic2_model.score(X_train,y_train)
print(Logistic2_model_score)
print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8599785407725322
# [[6271   59]
#  [ 985  141]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      6330
#            1       0.70      0.13      0.21      1126
#
#     accuracy                           0.86      7456
#    macro avg       0.78      0.56      0.57      7456
# weighted avg       0.84      0.86      0.82      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %%
# predict probabilities
probs = Logistic2_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.768

# %%
y_test_predict=Logistic2_model.predict(X_test)
Logistic2_model_score=Logistic2_model.score(X_test,y_test)
print(Logistic2_model_score)
print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8610763454317898
# [[2676   26]
#  [ 418   76]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      2702
#            1       0.75      0.15      0.26       494
#
#     accuracy                           0.86      3196
#    macro avg       0.80      0.57      0.59      3196
# weighted avg       0.85      0.86      0.82      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
probs_test = Logistic2_model.predict_proba(X_test)

probs_test = probs_test[:, 1]

auc = roc_auc_score(y_test, probs_test)
print('AUC: %.3f' % auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs_test)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.780

# %% [markdown]
# ##### We can clearly see that the above logistic base and tuned model have the same scores and hence both are a good fit.

# %% [markdown]
# ### Discriminant Analysis LDA for Laptop dataset

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA_model=LinearDiscriminantAnalysis()
LDA_model.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_train_predict=LDA_model.predict(X_train)
LDA_model_score=LDA_model.score(X_train,y_train)
print(LDA_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8193548387096774
# [[568  26]
#  [114  67]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       594
#            1       0.72      0.37      0.49       181
#
#     accuracy                           0.82       775
#    macro avg       0.78      0.66      0.69       775
# weighted avg       0.81      0.82      0.80       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
y_test_predict=LDA_model.predict(X_test)
LDA_model_score=LDA_model.score(X_test,y_test)
print(LDA_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.7957957957957958
# [[227  11]
#  [ 57  38]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87       238
#            1       0.78      0.40      0.53        95
#
#     accuracy                           0.80       333
#    macro avg       0.79      0.68      0.70       333
# weighted avg       0.79      0.80      0.77       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Discriminant Analysis LDA for Mobile dataset

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA_model=LinearDiscriminantAnalysis()
LDA_model.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_train_predict=LDA_model.predict(X_train)
LDA_model_score=LDA_model.score(X_train,y_train)
print(LDA_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8625268240343348
# [[6253   77]
#  [ 948  178]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92      6330
#            1       0.70      0.16      0.26      1126
#
#     accuracy                           0.86      7456
#    macro avg       0.78      0.57      0.59      7456
# weighted avg       0.84      0.86      0.82      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix MObile')
plt.show()

# %%
y_test_predict=LDA_model.predict(X_test)
LDA_model_score=LDA_model.score(X_test,y_test)
print(LDA_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8620150187734669
# [[2666   36]
#  [ 405   89]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92      2702
#            1       0.71      0.18      0.29       494
#
#     accuracy                           0.86      3196
#    macro avg       0.79      0.58      0.61      3196
# weighted avg       0.84      0.86      0.83      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %% [markdown]
# ### Naive Bayes for laptop dataset

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
X_train,X_test, y_train, y_test=train_test_split(X,y,train_size=0.70, random_state=1)

# %%
NB_model=GaussianNB()
NB_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_predict=NB_model.predict(X_train)
model_score=NB_model.score(X_train, y_train)
print(model_score)
# Out:
# 0.8193548387096774

# %%
y_train_predict=NB_model.predict(X_train)
NB_model=NB_model.score(X_train,y_train)
print(NB_model)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8193548387096774
# [[572  22]
#  [118  63]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       594
#            1       0.74      0.35      0.47       181
#
#     accuracy                           0.82       775
#    macro avg       0.79      0.66      0.68       775
# weighted avg       0.81      0.82      0.79       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Naive Base')
plt.show()

# %%
NB_model=GaussianNB()
NB_model.fit(X_test, y_test)
# Out:
# GaussianNB()

# %%
y_test_predict=NB_model.predict(X_test)
model_score=NB_model.score(X_test, y_test)
print(model_score)
# Out:
# 0.7897897897897898

# %%
y_test_predict=NB_model.predict(X_test)
NB_model=NB_model.score(X_test,y_test)
print(NB_model)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.7897897897897898
# [[201  37]
#  [ 33  62]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       238
#            1       0.63      0.65      0.64        95
#
#     accuracy                           0.79       333
#    macro avg       0.74      0.75      0.75       333
# weighted avg       0.79      0.79      0.79       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Naive Base')
plt.show()

# %% [markdown]
# ### Naive Bayes for Mobile dataset

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
NB_model=GaussianNB()
NB_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_predict=NB_model.predict(X_train)
NB_model=NB_model.score(X_train,y_train)
print(NB_model)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8532725321888412
# [[6292   38]
#  [1056   70]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      6330
#            1       0.65      0.06      0.11      1126
#
#     accuracy                           0.85      7456
#    macro avg       0.75      0.53      0.52      7456
# weighted avg       0.82      0.85      0.80      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %%
NB_model=GaussianNB()
NB_model.fit(X_test, y_test)
# Out:
# GaussianNB()

# %%
y_test_predict=NB_model.predict(X_test)
model_score=NB_model.score(X_test, y_test)
print(model_score)
# Out:
# 0.8560700876095119

# %%
y_test_predict=NB_model.predict(X_test)
NB_model=NB_model.score(X_test,y_test)
print(NB_model)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8560700876095119
# [[2690   12]
#  [ 448   46]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      2702
#            1       0.79      0.09      0.17       494
#
#     accuracy                           0.86      3196
#    macro avg       0.83      0.54      0.54      3196
# weighted avg       0.85      0.86      0.80      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Mobile')
plt.show()

# %% [markdown]
# ### Ensemble techniques

# %% [markdown]
# #### Bagging using hyperparameters for laptop dataset

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bc = BaggingClassifier(base_estimator=rf, oob_score=True, random_state=1)

# %%
params = {'n_estimators': [40, 42], 'base_estimator__max_leaf_nodes':[10, 15], 'base_estimator__max_depth':[4, 5, 6]}

# %%
# Grid Search to determine best parameters
bc_grid = GridSearchCV(estimator=bc, param_grid=params, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
bc_grid.fit(X_train, y_train)
best_params = bc_grid.best_params_
print(best_params)
# Out:
# {'base_estimator__max_depth': 6, 'base_estimator__max_leaf_nodes': 15, 'n_estimators': 42}

# %%
rf = RandomForestClassifier(max_leaf_nodes=15, max_depth=6)                   
bc = BaggingClassifier(base_estimator=rf, n_estimators=42, random_state=1, oob_score=True)

# %%
bc.fit(X_train, y_train)
final_preds = bc.predict(X_test)

# %%
y_train_predict=bc.predict(X_train)
model_score=bc.score(X_train, y_train)
print(model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8787096774193548
# [[594   0]
#  [ 94  87]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       594
#            1       1.00      0.48      0.65       181
#
#     accuracy                           0.88       775
#    macro avg       0.93      0.74      0.79       775
# weighted avg       0.90      0.88      0.86       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix laptop')
plt.show()

# %%
y_test_predict=bc.predict(X_test)
model_score=bc.score(X_test, y_test)
print(model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8648648648648649
# [[238   0]
#  [ 45  50]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       238
#            1       1.00      0.53      0.69        95
#
#     accuracy                           0.86       333
#    macro avg       0.92      0.76      0.80       333
# weighted avg       0.89      0.86      0.85       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix laptop')
plt.show()

# %% [markdown]
# #### Bagging using hyperparameters for mobile dataset

# %%
X = df2_mobile.drop('Taken_product', axis=1)
y = df2_mobile['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bc = BaggingClassifier(base_estimator=rf, oob_score=True, random_state=1)

# %%
params = {'n_estimators': [40, 42], 'base_estimator__max_leaf_nodes':[10, 15], 'base_estimator__max_depth':[4, 5, 6]}

# %%
# Grid Search to determine best parameters
bc_grid = GridSearchCV(estimator=bc, param_grid=params, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
bc_grid.fit(X_train, y_train)
best_params = bc_grid.best_params_
print(best_params)
# Out:
# {'base_estimator__max_depth': 6, 'base_estimator__max_leaf_nodes': 15, 'n_estimators': 40}

# %%
rf = RandomForestClassifier(max_leaf_nodes=15, max_depth=6)                   
bc = BaggingClassifier(base_estimator=rf, n_estimators=40, random_state=1, oob_score=True)

# %%
bc.fit(X_train, y_train)
final_preds = bc.predict(X_test)

# %%
y_train_predict=bc.predict(X_train)
model_score=bc.score(X_train, y_train)
print(model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8677575107296137
# [[6317   13]
#  [ 973  153]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6330
#            1       0.92      0.14      0.24      1126
#
#     accuracy                           0.87      7456
#    macro avg       0.89      0.57      0.58      7456
# weighted avg       0.87      0.87      0.82      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix laptop')
plt.show()

# %%
y_test_predict=bc.predict(X_test)
model_score=bc.score(X_test, y_test)
print(model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.867334167709637
# [[2695    7]
#  [ 417   77]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      2702
#            1       0.92      0.16      0.27       494
#
#     accuracy                           0.87      3196
#    macro avg       0.89      0.58      0.60      3196
# weighted avg       0.87      0.87      0.82      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix laptop')
plt.show()

# %% [markdown]
# ### Bagging without grid search laptop dataset

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
rf=RandomForestClassifier()
Bagging_model=BaggingClassifier()

Bagging_model.fit(X_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_train_predict=Bagging_model.predict(X_train)
Bagging_model_score=Bagging_model.score(X_train,y_train)
print(Bagging_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.9961290322580645
# [[594   0]
#  [  3 178]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       594
#            1       1.00      0.98      0.99       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      0.99      0.99       775
# weighted avg       1.00      1.00      1.00       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Baggingtrain laptop')
plt.show()

# %%
y_test_predict=Bagging_model.predict(X_test)
Bagging_model_score=Bagging_model.score(X_test,y_test)
print(Bagging_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.9819819819819819
# [[238   0]
#  [  6  89]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       238
#            1       1.00      0.94      0.97        95
#
#     accuracy                           0.98       333
#    macro avg       0.99      0.97      0.98       333
# weighted avg       0.98      0.98      0.98       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Baggingtest laptop')
plt.show()

# %% [markdown]
# ### Bagging without grid search Mobile dataset

# %%
X = df2_mobile.drop('Taken_product', axis=1)
y = df2_mobile['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
rf=RandomForestClassifier()
Bagging_model=BaggingClassifier()

Bagging_model.fit(X_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_train_predict=Bagging_model.predict(X_train)
Bagging_model_score=Bagging_model.score(X_train,y_train)
print(Bagging_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.9983905579399142
# [[6329    1]
#  [  11 1115]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6330
#            1       1.00      0.99      0.99      1126
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Baggingtrain mobile')
plt.show()

# %%
y_test_predict=Bagging_model.predict(X_test)
Bagging_model_score=Bagging_model.score(X_test,y_test)
print(Bagging_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.9831038798498123
# [[2692   10]
#  [  44  450]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2702
#            1       0.98      0.91      0.94       494
#
#     accuracy                           0.98      3196
#    macro avg       0.98      0.95      0.97      3196
# weighted avg       0.98      0.98      0.98      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Baggingtest mobile')
plt.show()

# %% [markdown]
# ### ADA Boosting Model for laptop

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
df1_laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  1   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  2   yearly_avg_Outstation_checkins                1108 non-null   float64
#  3   member_in_family                              1108 non-null   int64
#  4   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  5   total_likes_on_outofstation_checkin_received  1108 non-null   int64
#  6   week_since_last_outstation_checkin            1108 non-null   int64
#  7   following_company_page                        1108 non-null   float64
#  8   travelling_network_rating                     1108 non-null   int64
#  9   Adult_flag                                    1108 non-null   int64
#  10  Taken_product                                 1108 non-null   int64
# dtypes: float64(5), int64(6)
# memory usage: 103.9 KB

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
ADB_model=AdaBoostClassifier()
ADB_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_train_predict=ADB_model.predict(X_train)
ADB_model_score=ADB_model.score(X_train,y_train)
print(ADB_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.9032258064516129
# [[578  16]
#  [ 59 122]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       594
#            1       0.88      0.67      0.76       181
#
#     accuracy                           0.90       775
#    macro avg       0.90      0.82      0.85       775
# weighted avg       0.90      0.90      0.90       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix ADAboost laptop')
plt.show()

# %%
y_test_predict = ADB_model.predict(X_test)
ADB_model_score = ADB_model.score(X_test, y_test)
print(ADB_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8768768768768769
# [[226  12]
#  [ 29  66]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       238
#            1       0.85      0.69      0.76        95
#
#     accuracy                           0.88       333
#    macro avg       0.87      0.82      0.84       333
# weighted avg       0.87      0.88      0.87       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix ADAboost laptop')
plt.show()

# %% [markdown]
# ### ADA Boosting Model for mobile

# %%
X = df2_mobile.drop('Taken_product', axis=1)
y = df2_mobile['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
ADB_model=AdaBoostClassifier()
ADB_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_train_predict=ADB_model.predict(X_train)
ADB_model_score=ADB_model.score(X_train,y_train)
print(ADB_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.877280042918455
# [[6224  106]
#  [ 809  317]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      6330
#            1       0.75      0.28      0.41      1126
#
#     accuracy                           0.88      7456
#    macro avg       0.82      0.63      0.67      7456
# weighted avg       0.86      0.88      0.85      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix ADAboost MObile')
plt.show()

# %%
y_test_predict = ADB_model.predict(X_test)
ADB_model_score = ADB_model.score(X_test, y_test)
print(ADB_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8704630788485607
# [[2637   65]
#  [ 349  145]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      2702
#            1       0.69      0.29      0.41       494
#
#     accuracy                           0.87      3196
#    macro avg       0.79      0.63      0.67      3196
# weighted avg       0.85      0.87      0.85      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix ADAboost Mobile')
plt.show()

# %% [markdown]
# ### Gradient Boosting for laptop

# %%
X = df1_laptop.drop('Taken_product', axis=1)
y = df1_laptop['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc_model=GradientBoostingClassifier()
gbc_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_train_predict = gbc_model.predict(X_train)
gbc_model_score = gbc_model.score(X_train, y_train)
print(gbc_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.9819354838709677
# [[594   0]
#  [ 14 167]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       594
#            1       1.00      0.92      0.96       181
#
#     accuracy                           0.98       775
#    macro avg       0.99      0.96      0.97       775
# weighted avg       0.98      0.98      0.98       775

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Gradientboost laptop')
plt.show()

# %%
y_test_predict = gbc_model.predict(X_test)
gbc_model_score = gbc_model.score(X_test, y_test)
print(gbc_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.954954954954955
# [[235   3]
#  [ 12  83]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       238
#            1       0.97      0.87      0.92        95
#
#     accuracy                           0.95       333
#    macro avg       0.96      0.93      0.94       333
# weighted avg       0.96      0.95      0.95       333

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Gradientboos laptop')
plt.show()

# %% [markdown]
# ### Gradient Boosting for Mobile

# %%
X = df2_mobile.drop('Taken_product', axis=1)
y = df2_mobile['Taken_product']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
gbc_model=GradientBoostingClassifier()
gbc_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_train_predict = gbc_model.predict(X_train)
gbc_model_score = gbc_model.score(X_train, y_train)
print(gbc_model_score)

print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.9110783261802575
# [[6269   61]
#  [ 602  524]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      6330
#            1       0.90      0.47      0.61      1126
#
#     accuracy                           0.91      7456
#    macro avg       0.90      0.73      0.78      7456
# weighted avg       0.91      0.91      0.90      7456

# %%
confusion_matrix(y_train,y_train_predict)
sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Gradientboost MObile')
plt.show()

# %%
y_test_predict = gbc_model.predict(X_test)
gbc_model_score = gbc_model.score(X_test, y_test)
print(gbc_model_score)

print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.9020650813516896
# [[2669   33]
#  [ 280  214]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.94      2702
#            1       0.87      0.43      0.58       494
#
#     accuracy                           0.90      3196
#    macro avg       0.89      0.71      0.76      3196
# weighted avg       0.90      0.90      0.89      3196

# %%
confusion_matrix(y_test,y_test_predict)
sns.heatmap(confusion_matrix(y_test,y_test_predict),annot=True, fmt='d',cbar=False, cmap='Accent')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix Gradientboos mobile')
plt.show()
